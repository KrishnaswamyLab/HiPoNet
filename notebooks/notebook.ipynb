# %%
import scanpy as sc

# Load the .h5ad file
adata = sc.read_h5ad('2m_pdo.h5ad')

# %%
adata.obs
# Out:
#                                                        Date Patient Culture  \
# 4022175   0           20211119\n1           20211119\n2 ...     216     PDO
# 11355818  0           20211119\n1           20211119\n2 ...      11    PDOF
# 18993655  0           20211119\n1           20211119\n2 ...      23    PDOF
# 16859228  0           20211119\n1           20211119\n2 ...     216     PDO
# 14160310  0           20211119\n1           20211119\n2 ...     216     PDO
# ...                                                     ...     ...     ...
# 17930646  0           20211119\n1           20211119\n2 ...     109     PDO
# 701854    0           20211119\n1           20211119\n2 ...      11    PDOF
# 8973584   0           20211119\n1           20211119\n2 ...       5    PDOF
# 14000620  0           20211119\n1           20211119\n2 ...     216     PDO
# 22562184  0           20211119\n1           20211119\n2 ...       5    PDOF
#
# ...
